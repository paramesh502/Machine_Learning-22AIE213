# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (2.2.6)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Parameshwar-bl.sc.u4aie24008-set_b

# %%
import numpy as np

def vowels_consonants(word):
    vowels = "aeiouAEIOU"
    v_count = 0
    c_count = 0
    for x in word:
        if x.isalpha():
            if x in vowels:
                v_count += 1
            else:
                c_count += 1
    return v_count, c_count

def multiply_matrics(A, B):
    a = np.array(A)
    b = np.array(B)
    if a.shape[1] != b.shape[0]:
        return "Error"
    result = np.dot(a, b)
    return result

def common_elements(l1,l2):
    s1 = set(l1)
    s2 = set(l2)
    common = s1.intersection(s2)
    return len(common)

def get_transpose(matrix):
    m = np.array(matrix)
    transpose = np.transpose(m)
    return transpose

def mean_mode_median(numbers):
    numbers.sort()
    total = sum(numbers)
    mean = total / len(numbers)
    median = (numbers[49] + numbers[50])/2
    freq = {}
    for n in numbers:
        freq[n] = freq.get(n, 0) + 1
    mode = max(freq, key=freq.get)
    return mean, mode, median

if __name__ == "__main__":
    word = "paramesh"
    v,c = vowels_consonants(word)
    print("que1:")
    print(f"Vowels: {v}, Consonants: {c}")   

    A = [[1, 2, 3], [4, 5, 6]]
    B = [[3], [2], [1]]
    print("que2:")
    print("Matrix Multiplication Result:")
    print(multiply_matrics(A, B))   

    l1 = [18,45,7,1]
    l2 = [17,18,333]
    print("que3:")
    print(f"Common elements count: {common_elements(l1, l2)}")

    mtrix = [[1,5,7], [0,0,0], [7,5,3]]
    print("que4:")
    print("Transpose of matrix:")
    print(get_transpose(mtrix))

    numbers = list(np.random.randint(101,150,100))
    mean, mode, median = mean_mode_median(numbers)
    print("que5:")
    print(numbers)
    print(f"Mean: {mean}, Mode: {mode}, Median: {median}")
# Out:
# que1:
# Vowels: 3, Consonants: 5
# que2:
# Matrix Multiplication Result:
# [[10]
#  [28]]
# que3:
# Common elements count: 1
# que4:
# Transpose of matrix:
# [[1 0 7]
#  [5 0 5]
#  [7 0 3]]
# que5:
# [np.int64(101), np.int64(101), np.int64(101), np.int64(102), np.int64(103), np.int64(103), np.int64(104), np.int64(104), np.int64(104), np.int64(104), np.int64(105), np.int64(105), np.int64(106), np.int64(106), np.int64(107), np.int64(107), np.int64(107), np.int64(107), np.int64(108), np.int64(109), np.int64(109), np.int64(111), np.int64(112), np.int64(112), np.int64(112), np.int64(113), np.int64(113), np.int64(113), np.int64(113), np.int64(114), np.int64(114), np.int64(114), np.int64(115), np.int64(115), np.int64(116), np.int64(116), np.int64(117), np.int64(118), np.int64(119), np.int64(119), np.int64(119), np.int64(119), np.int64(120), np.int64(120), np.int64(121), np.int64(122), np.int64(123), np.int64(123), np.int64(124), np.int64(124), np.int64(125), np.int64(126), np.int64(128), np.int64(130), np.int64(131), np.int64(131), np.int64(131), np.int64(131), np.int64(131), np.int64(132), np.int64(133), np.int64(133), np.int64(133), np.int64(133), np.int64(134), np.int64(136), np.int64(136), np.int64(137), np.int64(138), np.int64(138), np.int64(138), np.int64(139), np.int64(139), np.int64(140), np.int64(141), np.int64(141), np.int64(141), np.int64(141), np.int64(142), np.int64(142), np.int64(142), np.int64(143), np.int64(143), np.int64(143), np.int64(144), np.int64(144), np.int64(144), np.int64(145), np.int64(145), np.int64(146), np.int64(146), np.int64(147), np.int64(147), np.int64(147), np.int64(147), np.int64(148), np.int64(148), np.int64(148), np.int64(148), np.int64(149)]
# Mean: 125.59, Mode: 131, Median: 124.5
